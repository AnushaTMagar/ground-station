# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
df = pd.read_csv ('/content/flight_data2.csv')
print("_____________ Not Preprocessed Data _________________________")
df
# Out:
# _____________ Not Preprocessed Data _________________________
#       Acceleration_x  Acceleration_y  Acceleration_z  Gyro_x  Gyro_y  Gyro_z  \
# 0               0.09            1.02           -9.32   -0.03    0.03    0.03
# 1                NaN             NaN             NaN     NaN     NaN     NaN
# 2               0.07            1.00           -9.37   -0.03    0.03    0.03
# 3                NaN             NaN             NaN     NaN     NaN     NaN
# 4               0.08            1.03           -9.34   -0.03    0.03    0.03
# ...              ...             ...             ...     ...     ...     ...
# 1707            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1708            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1709            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1710            0.58            2.95            4.16    0.03   -0.03   -0.84
# ...

# %%
df = df.dropna()

# %%
print("____________________Preprocessed Data______________________")
df
# Out:
# ____________________Preprocessed Data______________________
#       Acceleration_x  Acceleration_y  Acceleration_z  Gyro_x  Gyro_y  Gyro_z  \
# 0               0.09            1.02           -9.32   -0.03    0.03    0.03
# 2               0.07            1.00           -9.37   -0.03    0.03    0.03
# 4               0.08            1.03           -9.34   -0.03    0.03    0.03
# 6               0.06            1.03           -9.37   -0.02    0.03    0.03
# 8               0.08            1.04           -9.35   -0.03    0.03    0.04
# ...              ...             ...             ...     ...     ...     ...
# 1707            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1708            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1709            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1710            0.58            2.95            4.16    0.03   -0.03   -0.84
# ...

# %%
connected = df.loc[df['Rflink'] == 1]
disconnected = df.loc[df['Rflink'] == 0]
connected = connected.reset_index()
disconnected = disconnected.reset_index()

# %%
print("_________________________________ Connected Data __________________________")
connected
# Out:
# _________________________________ Connected Data __________________________
#       Acceleration_x  Acceleration_y  Acceleration_z  Gyro_x  Gyro_y  Gyro_z  \
# 0               0.09            1.02           -9.32   -0.03    0.03    0.03
# 2               0.07            1.00           -9.37   -0.03    0.03    0.03
# 4               0.08            1.03           -9.34   -0.03    0.03    0.03
# 6               0.06            1.03           -9.37   -0.02    0.03    0.03
# 8               0.08            1.04           -9.35   -0.03    0.03    0.04
# ...              ...             ...             ...     ...     ...     ...
# 1704            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1705            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1706            0.58            2.95            4.16    0.03   -0.03   -0.84
# 1707            0.58            2.95            4.16    0.03   -0.03   -0.84
# ...

# %%
print("_____________________ Disconnected Data _______________________________-")
disconnected
# Out:
# _____________________ Disconnected Data _______________________________-
#       Acceleration_x  Acceleration_y  Acceleration_z  Gyro_x  Gyro_y  Gyro_z  \
# 32              0.07            1.01           -9.35   -0.03    0.03    0.03
# 178             0.07            1.03           -9.31   -0.03    0.03    0.03
# 394             0.08            1.01           -9.36   -0.03    0.03    0.03
# 428             0.04            1.03           -9.32   -0.03    0.03    0.03
# 436             0.08            1.02           -9.36   -0.03    0.03    0.03
# 480             0.07            1.02           -9.34   -0.03    0.03    0.03
# 594             0.06            1.03           -9.32   -0.03    0.03    0.03
# 778             0.07            1.04           -9.34   -0.03    0.03    0.03
# 784             0.08            1.04           -9.34   -0.03    0.03    0.03
# 828             0.06            1.03           -9.33   -0.03    0.03    0.03
# ...

# %%
print("________Connected Data Count_________")
connected.count()
# Out:
# ________Connected Data Count_________
# Acceleration_x    833
# Acceleration_y    833
# Acceleration_z    833
# Gyro_x            833
# Gyro_y            833
# Gyro_z            833
# Temperature       833
# Pressure          833
# Altitude          833
# Voltage           833
# Rflink            833
# dtype: int64

# %%
print("________Disconnected Data Count_________")
disconnected.count()
# Out:
# ________Disconnected Data Count_________
# Acceleration_x    28
# Acceleration_y    28
# Acceleration_z    28
# Gyro_x            28
# Gyro_y            28
# Gyro_z            28
# Temperature       28
# Pressure          28
# Altitude          28
# Voltage           28
# Rflink            28
# dtype: int64

# %%
print("_____________ Max Data __________________")
connected.max()
# Out:
# _____________ Max Data __________________
# Acceleration_x       0.58
# Acceleration_y      15.54
# Acceleration_z       4.16
# Gyro_x               0.03
# Gyro_y               0.10
# Gyro_z               0.23
# Temperature         40.20
# Pressure           985.21
# Altitude          1059.76
# Voltage              4.02
# Rflink               1.00
# dtype: float64

# %%
print("_____________ Min Data________________-")
connected.min()
# Out:
# _____________ Min Data________________-
# Acceleration_x     -1.72
# Acceleration_y      0.99
# Acceleration_z    -78.45
# Gyro_x             -0.30
# Gyro_y             -0.03
# Gyro_z             -0.84
# Temperature        37.49
# Pressure          981.07
# Altitude          236.18
# Voltage             3.65
# Rflink              1.00
# dtype: float64

# %%
print("___________________ All values at maximum Altitude________________________")
connected.loc[connected['Altitude'] == connected['Altitude'].max()]
# Out:
# ___________________ All values at maximum Altitude________________________
#       Acceleration_x  Acceleration_y  Acceleration_z  Gyro_x  Gyro_y  Gyro_z  \
# 1708            0.58            2.95            4.16    0.03   -0.03   -0.84
#
#       Temperature  Pressure  Altitude  Voltage  Rflink
# 1708        40.19    981.07   1059.76     3.72     1.0

# %%
plt.rcParams["figure.figsize"] = (35,10)
connected['Voltage'].plot()
plt.title("Plot of Voltage", fontsize= 20, fontweight='bold')
plt.xlabel('No. of Data', fontsize= 20, fontweight='bold')
plt.ylabel('Voltage', fontsize= 20, fontweight='bold')
# Out:
# Text(0, 0.5, 'Voltage')

# %%
connected['Altitude'].plot(style = '.')
plt.title("Plot of Altitude(Above Sea Level)", fontsize= 20, fontweight='bold')
plt.xlabel('No. of Data', fontsize= 20, fontweight='bold')
plt.ylabel('Altitude', fontsize= 20, fontweight='bold')
# Out:
# Text(0, 0.5, 'Altitude')

# %%
connected['Acceleration_x'].plot(label = 'Acceleration_x')
connected['Acceleration_y'].plot(label = 'Acceleration_y')
connected['Acceleration_z'].plot(label = 'Acceleration_z')
plt.title("Plot of Acceleration", fontsize= 20, fontweight='bold')
plt.xlabel('No. of Data', fontsize= 20, fontweight='bold')
plt.ylabel('Acceleration', fontsize= 20, fontweight='bold')
plt.legend()

# %%
plt.rcParams["figure.figsize"] = (25,10)
connected['Gyro_x'].plot(label = 'Gyro_x')
connected['Gyro_y'].plot(label = 'Gyro_y')
connected['Gyro_z'].plot(label = 'Gyro_z')
plt.title("Plot of Gyro", fontsize= 20, fontweight='bold')
plt.xlabel('No. of Data', fontsize= 20, fontweight='bold')
plt.ylabel('Gyro', fontsize= 20, fontweight='bold')
plt.legend()

# %%
plt.rcParams["figure.figsize"] = (25,10)
connected['Pressure'].plot(style = '.')
plt.title("Plot of Pressure", fontsize= 20, fontweight='bold')
plt.xlabel('No. of Data', fontsize= 20, fontweight='bold')
plt.ylabel('Pressure', fontsize= 20, fontweight='bold')
# Out:
# Text(0, 0.5, 'Pressure')

# %%
plt.rcParams["figure.figsize"] = (25,10)
connected['Temperature'].plot(style = '.')
plt.title("Plot of Temperature", fontsize= 20, fontweight='bold')
plt.xlabel('No. of Data', fontsize= 20, fontweight='bold')
plt.ylabel('Temperature', fontsize= 20, fontweight='bold')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
df['Rflink'].plot()
df['Rflink'].plot(style = '.')
plt.title("Plot of Rflink Status (0 is off and 1 is on)", fontsize= 20, fontweight='bold')
plt.xlabel('No. of Data', fontsize= 20, fontweight='bold')

plt.ylabel('Status', fontsize= 20, fontweight='bold')
# Out:
# Text(0, 0.5, 'Status')
